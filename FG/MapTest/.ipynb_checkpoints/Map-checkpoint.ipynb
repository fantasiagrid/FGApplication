# %% [markdown]
# # Common Libraries

# %%
import folium
import numpy as np
import pandas as pd
from folium import RegularPolygonMarker
import math
from datetime import datetime

# %% [markdown]
# # Constants

# %%
loc_map_focus = [37.565898, 127.055460]

test_number = 7

# %% [markdown]
# # Paths

# %%
location_data_path = f"/Users/seojin/Desktop/Locs/location_data{test_number}.csv"
event_location_data_path = f"/Users/seojin/Desktop/Locs/event_location_data{test_number}.csv"
coordinate_data_path = f"/Users/seojin/Desktop/Locs/coordinate{test_number}.csv"

# %% [markdown]
# # Load geographic data

# %%
location_df = pd.read_csv(location_data_path)
location_df = location_df[location_df["EventType"] == "Receive"]
location_df["Time"] = [datetime.fromisoformat(time.replace('Z', '+00:00')) for time in location_df["Time"]]

# %%
event_df = pd.read_csv(event_location_data_path)
event_df["Time"] = [datetime.fromisoformat(time.replace('Z', '+00:00')) for time in event_df["Time"]]
startTime = initTime - pd.Timedelta(seconds=20)
initTime = event_df[event_df["EventType"] == "ReferenceCoord"]["Time"].iloc[0]

# %%
location_df["seconds_fromStart"] = [e.total_seconds() for e in location_df["Time"] - startTime]
location_df["seconds_fromInit"] = [e.total_seconds() for e in location_df["Time"] - initTime]

# %%
coordinate_df = pd.read_csv(coordinate_data_path)
coordinate_df["Time"] = [datetime.fromisoformat(time.replace('Z', '+00:00')) for time in coordinate_df["Time"]]

# %%
stard_10 = location_df[(location_df["seconds_fromStart"] > 0) & (location_df["seconds_fromStart"] < 10)]
stard_10[["Latitude", "Longitude"]].mean().to_numpy()
# Out:
# array([ 37.56589958, 127.05544897])

# %%
end_10 = location_df[(location_df["seconds_fromInit"] < 0) & (location_df["seconds_fromInit"] > -10)]
end_10[["Latitude", "Longitude"]].mean().to_numpy()
# Out:
# array([ 37.5659579 , 127.05531265])

# %% [markdown]
# # Map

# %%
start = event_df[event_df["EventType"] == "startCoord"].iloc[-1]
start_loc = start[["Latitude", "Longitude"]].to_numpy().astype(np.float64)

reference = event_df[event_df["EventType"] == "ReferenceCoord"].iloc[-1]
reference_loc = reference[["Latitude", "Longitude"]].to_numpy().astype(np.float64)

# %%
# 지도 생성 (서울 좌표 기준)
m = folium.Map(location = loc_map_focus, zoom_start=18)

# folium.PolyLine(locations=line_points, color='blue', weight=5, opacity=0.8).add_to(m)
folium.Marker(start_loc, popup = "Start", icon=folium.Icon(color="red")).add_to(m)
folium.Marker(reference_loc, popup = "Ref", icon=folium.Icon(color="blue")).add_to(m)
folium.Marker([37.565898, 127.055460], popup = "Object", icon=folium.Icon(color="pink")).add_to(m)

# folium.RegularPolygonMarker(location = line_points[0], fill_color = 'blue', number_of_sides = 3, radius = 10, rotation = 100).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aaf5dbc8daf9545c4b839c72ec5872b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aaf5dbc8daf9545c4b839c72ec5872b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aaf5dbc8daf9545c4b839c72ec5872b6 = L.map(
#                 &quot;map_aaf5dbc8daf9545c4b839c72ec5872b6&quot;,
#                 {
#                     center: [37.565898, 127.05546],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 18,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eeb09c8e687ec96c6f96d1e239ab03dd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eeb09c8e687ec96c6f96d1e239ab03dd.addTo(map_aaf5dbc8daf9545c4b839c72ec5872b6);
#
#
#             var marker_cd6464cd4956656116c086652c96ecf9 = L.marker(
#                 [37.56587348179436, 127.05539112409689],
#                 {
# }
#             ).addTo(map_aaf5dbc8daf9545c4b839c72ec5872b6);
#
#
#             var icon_6082bcdc4bd3bc7d8c0ee3b2eab7b98f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_82e92ffc3ebc63ee7a5619efcba8f99f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7c6f2a630938ea4be44ce438b842f96 = $(`&lt;div id=&quot;html_c7c6f2a630938ea4be44ce438b842f96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start&lt;/div&gt;`)[0];
#                 popup_82e92ffc3ebc63ee7a5619efcba8f99f.setContent(html_c7c6f2a630938ea4be44ce438b842f96);
#
#
#
#         marker_cd6464cd4956656116c086652c96ecf9.bindPopup(popup_82e92ffc3ebc63ee7a5619efcba8f99f)
#         ;
#
#
#
#
#                 marker_cd6464cd4956656116c086652c96ecf9.setIcon(icon_6082bcdc4bd3bc7d8c0ee3b2eab7b98f);
#
#
#             var marker_6dc38d985b0fa21eb15bb3da9f15bf4a = L.marker(
#                 [37.56595252993108, 127.05532454589994],
#                 {
# }
#             ).addTo(map_aaf5dbc8daf9545c4b839c72ec5872b6);
#
#
#             var icon_ab5b75476bbdbca3035a040c06a05cc7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e185b5824b43e39cb7e9b6c4acf46b72 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12ceca3dc7fe06efcbed173d0caf088a = $(`&lt;div id=&quot;html_12ceca3dc7fe06efcbed173d0caf088a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ref&lt;/div&gt;`)[0];
#                 popup_e185b5824b43e39cb7e9b6c4acf46b72.setContent(html_12ceca3dc7fe06efcbed173d0caf088a);
#
#
#
#         marker_6dc38d985b0fa21eb15bb3da9f15bf4a.bindPopup(popup_e185b5824b43e39cb7e9b6c4acf46b72)
#         ;
#
#
#
#
#                 marker_6dc38d985b0fa21eb15bb3da9f15bf4a.setIcon(icon_ab5b75476bbdbca3035a040c06a05cc7);
#
#
#             var marker_0b4426d7f2db46f248cad9c2e854bd3f = L.marker(
#                 [37.565898, 127.05546],
#                 {
# }
#             ).addTo(map_aaf5dbc8daf9545c4b839c72ec5872b6);
#
#
#             var icon_c3b6f3cf4c92ba45ec59d50b5efcf21d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;pink&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e8016957fd3fe1f51f852843fd55fd83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3801c11b0b41653923c6c3f7fed5042d = $(`&lt;div id=&quot;html_3801c11b0b41653923c6c3f7fed5042d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Object&lt;/div&gt;`)[0];
#                 popup_e8016957fd3fe1f51f852843fd55fd83.setContent(html_3801c11b0b41653923c6c3f7fed5042d);
#
#
#
#         marker_0b4426d7f2db46f248cad9c2e854bd3f.bindPopup(popup_e8016957fd3fe1f51f852843fd55fd83)
#         ;
#
#
#
#
#                 marker_0b4426d7f2db46f248cad9c2e854bd3f.setIcon(icon_c3b6f3cf4c92ba45ec59d50b5efcf21d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location = loc_map_focus, zoom_start=18)
for lat, long in zip(stard_10["Latitude"], stard_10["Longitude"]):
    folium.Marker([lat, long], popup = "Start", icon=folium.Icon(color="red")).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31db8e5d9f04ee19f9b12ebe341e7f51 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31db8e5d9f04ee19f9b12ebe341e7f51&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31db8e5d9f04ee19f9b12ebe341e7f51 = L.map(
#                 &quot;map_31db8e5d9f04ee19f9b12ebe341e7f51&quot;,
#                 {
#                     center: [37.565898, 127.05546],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 18,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f1c773d13e8550b1b5a3983bd3b0ae16 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f1c773d13e8550b1b5a3983bd3b0ae16.addTo(map_31db8e5d9f04ee19f9b12ebe341e7f51);
#
#
#             var marker_c4ff7d1d146e6ac66e22af66dcc704b2 = L.marker(
#                 [37.56590010136153, 127.05545263376744],
#                 {
# }
#             ).addTo(map_31db8e5d9f04ee19f9b12ebe341e7f51);
#
#
#             var icon_5c710c387fa953c96a8cb77e39b41c52 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3e6e03660f1f0f3e3bba22e020007e6d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_468e2d668335cbe448b0dc0a8e82e4a6 = $(`&lt;div id=&quot;html_468e2d668335cbe448b0dc0a8e82e4a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start&lt;/div&gt;`)[0];
#                 popup_3e6e03660f1f0f3e3bba22e020007e6d.setContent(html_468e2d668335cbe448b0dc0a8e82e4a6);
#
#
#
#         marker_c4ff7d1d146e6ac66e22af66dcc704b2.bindPopup(popup_3e6e03660f1f0f3e3bba22e020007e6d)
#         ;
#
#
#
#
#                 marker_c4ff7d1d146e6ac66e22af66dcc704b2.setIcon(icon_5c710c387fa953c96a8cb77e39b41c52);
#
#
#             var marker_2f82e7f62ca84ce36a7fd1ce059e4ab1 = L.marker(
#                 [37.56590010136153, 127.05545263376744],
#                 {
# }
#             ).addTo(map_31db8e5d9f04ee19f9b12ebe341e7f51);
#
#
#             var icon_c8385db6ac75c35c7bb276f3b7392b15 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_82debee8b7e150a82d5dc5c411bc8e63 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d24aa5b6775286df084f8de9d6c495e3 = $(`&lt;div id=&quot;html_d24aa5b6775286df084f8de9d6c495e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start&lt;/div&gt;`)[0];
#                 popup_82debee8b7e150a82d5dc5c411bc8e63.setContent(html_d24aa5b6775286df084f8de9d6c495e3);
#
#
#
#         marker_2f82e7f62ca84ce36a7fd1ce059e4ab1.bindPopup(popup_82debee8b7e150a82d5dc5c411bc8e63)
#         ;
#
#
#
#
#                 marker_2f82e7f62ca84ce36a7fd1ce059e4ab1.setIcon(icon_c8385db6ac75c35c7bb276f3b7392b15);
#
#
#             var marker_3b28657e3388a584d8c7d29b134e21ec = L.marker(
#                 [37.56590010136153, 127.05545263376744],
#                 {
# }
#             ).addTo(map_31db8e5d9f04ee19f9b12ebe341e7f51);
#
#
#             var icon_8a14b9dcc1373097ffbc3447fa71bf10 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_292d57e8964ae655ccdae07ca0ede9fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72774e55713048f403cc671ef6c06ed8 = $(`&lt;div id=&quot;html_72774e55713048f403cc671ef6c06ed8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start&lt;/div&gt;`)[0];
#                 popup_292d57e8964ae655ccdae07ca0ede9fc.setContent(html_72774e55713048f403cc671ef6c06ed8);
#
#
#
#         marker_3b28657e3388a584d8c7d29b134e21ec.bindPopup(popup_292d57e8964ae655ccdae07ca0ede9fc)
#         ;
#
#
#
#
#                 marker_3b28657e3388a584d8c7d29b134e21ec.setIcon(icon_8a14b9dcc1373097ffbc3447fa71bf10);
#
#
#             var marker_370dc58a45375bd1986f4788e7920f43 = L.marker(
#                 [37.56590010136153, 127.05545263376744],
#                 {
# }
#             ).addTo(map_31db8e5d9f04ee19f9b12ebe341e7f51);
#
#
#             var icon_f76bbc5db62e34f2

# %%
m = folium.Map(location = loc_map_focus, zoom_start=18)
for lat, long in zip(end_10["Latitude"], end_10["Longitude"]):
    folium.Marker([lat, long], popup = "Ref", icon=folium.Icon(color="blue")).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f511ffca622a8cdd8f73c23cb0b4747 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f511ffca622a8cdd8f73c23cb0b4747&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0f511ffca622a8cdd8f73c23cb0b4747 = L.map(
#                 &quot;map_0f511ffca622a8cdd8f73c23cb0b4747&quot;,
#                 {
#                     center: [37.565898, 127.05546],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 18,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15dd18072a5adf60bb6eb3350119888e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_15dd18072a5adf60bb6eb3350119888e.addTo(map_0f511ffca622a8cdd8f73c23cb0b4747);
#
#
#             var marker_1024da70ca6dea28832a60cffd1d99cc = L.marker(
#                 [37.56589879734529, 127.05544347893324],
#                 {
# }
#             ).addTo(map_0f511ffca622a8cdd8f73c23cb0b4747);
#
#
#             var icon_db8163c82956929db71be936ceb13565 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8d1cf3eb1186055e4b0ff3aa39c241cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23351185add2e3d42063cf63b8498cf1 = $(`&lt;div id=&quot;html_23351185add2e3d42063cf63b8498cf1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ref&lt;/div&gt;`)[0];
#                 popup_8d1cf3eb1186055e4b0ff3aa39c241cd.setContent(html_23351185add2e3d42063cf63b8498cf1);
#
#
#
#         marker_1024da70ca6dea28832a60cffd1d99cc.bindPopup(popup_8d1cf3eb1186055e4b0ff3aa39c241cd)
#         ;
#
#
#
#
#                 marker_1024da70ca6dea28832a60cffd1d99cc.setIcon(icon_db8163c82956929db71be936ceb13565);
#
#
#             var marker_c047ef0c54a924109823cfa243d3646c = L.marker(
#                 [37.56589884491565, 127.05544381290048],
#                 {
# }
#             ).addTo(map_0f511ffca622a8cdd8f73c23cb0b4747);
#
#
#             var icon_7eb1e47cbb6f60359ba852996d7d398b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ebe3d598a8834f358ad9d5dc7f0914aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d94784de93b138370021faa060561da = $(`&lt;div id=&quot;html_0d94784de93b138370021faa060561da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ref&lt;/div&gt;`)[0];
#                 popup_ebe3d598a8834f358ad9d5dc7f0914aa.setContent(html_0d94784de93b138370021faa060561da);
#
#
#
#         marker_c047ef0c54a924109823cfa243d3646c.bindPopup(popup_ebe3d598a8834f358ad9d5dc7f0914aa)
#         ;
#
#
#
#
#                 marker_c047ef0c54a924109823cfa243d3646c.setIcon(icon_7eb1e47cbb6f60359ba852996d7d398b);
#
#
#             var marker_e75009b5325a6dd2acf6a70ed60f6a4b = L.marker(
#                 [37.56589884570702, 127.05544381845628],
#                 {
# }
#             ).addTo(map_0f511ffca622a8cdd8f73c23cb0b4747);
#
#
#             var icon_6a1e382c0a08afd635908919011ead2a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_98284b93a6812cf6cb4b9805003e965e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79529f26dbceba519bd9fdcd95fd1b36 = $(`&lt;div id=&quot;html_79529f26dbceba519bd9fdcd95fd1b36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ref&lt;/div&gt;`)[0];
#                 popup_98284b93a6812cf6cb4b9805003e965e.setContent(html_79529f26dbceba519bd9fdcd95fd1b36);
#
#
#
#         marker_e75009b5325a6dd2acf6a70ed60f6a4b.bindPopup(popup_98284b93a6812cf6cb4b9805003e965e)
#         ;
#
#
#
#
#                 marker_e75009b5325a6dd2acf6a70ed60f6a4b.setIcon(icon_6a1e382c0a08afd635908919011ead2a);
#
#
#             var marker_8e49e2d80726463ef6e0cb3db4b6067b = L.marker(
#                 [37.56589884570718, 127.05544381845738],
#                 {
# }
#             ).addTo(map_0f511ffca622a8cdd8f73c23cb0b4747);
#
#
#             var icon_e1c363373a9c633f7f4
