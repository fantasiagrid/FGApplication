# %% [markdown]
# # Common Libraries

# %%
import folium
import numpy as np
import pandas as pd
from folium import RegularPolygonMarker
import math
from datetime import datetime

# %% [markdown]
# # Constants

# %%
loc_map_focus = [37.565898, 127.055460]

test_number = 7

# %% [markdown]
# # Paths

# %%
location_data_path = f"/Users/seojin/Desktop/Locs/location_data{test_number}.csv"
event_location_data_path = f"/Users/seojin/Desktop/Locs/event_location_data{test_number}.csv"
coordinate_data_path = f"/Users/seojin/Desktop/Locs/coordinate{test_number}.csv"

# %% [markdown]
# # Load geographic data

# %%
location_df = pd.read_csv(location_data_path)
location_df = location_df[location_df["EventType"] == "Receive"]
location_df["Time"] = [datetime.fromisoformat(time.replace('Z', '+00:00')) for time in location_df["Time"]]

# %%
event_df = pd.read_csv(event_location_data_path)
event_df["Time"] = [datetime.fromisoformat(time.replace('Z', '+00:00')) for time in event_df["Time"]]
initTime = event_df[event_df["EventType"] == "ReferenceCoord"]["Time"].iloc[0]
startTime = initTime - pd.Timedelta(seconds=20)

# %%
location_df["seconds_fromStart"] = [e.total_seconds() for e in location_df["Time"] - startTime]
location_df["seconds_fromInit"] = [e.total_seconds() for e in location_df["Time"] - initTime]

# %%
coordinate_df = pd.read_csv(coordinate_data_path)
coordinate_df["Time"] = [datetime.fromisoformat(time.replace('Z', '+00:00')) for time in coordinate_df["Time"]]

# %%
stard_10 = location_df[(location_df["seconds_fromStart"] > 0) & (location_df["seconds_fromStart"] < 10)]
stard_10[["Latitude", "Longitude"]].mean().to_numpy()
# Out:
# array([ 37.56589958, 127.05544897])

# %%
end_10 = location_df[(location_df["seconds_fromInit"] < 0) & (location_df["seconds_fromInit"] > -10)]
end_10[["Latitude", "Longitude"]].mean().to_numpy()
# Out:
# array([ 37.5659579 , 127.05531265])

# %% [markdown]
# # Map

# %%
start = event_df[event_df["EventType"] == "startCoord"].iloc[-1]
start_loc = start[["Latitude", "Longitude"]].to_numpy().astype(np.float64)

reference = event_df[event_df["EventType"] == "ReferenceCoord"].iloc[-1]
reference_loc = reference[["Latitude", "Longitude"]].to_numpy().astype(np.float64)

# %%
start_loc = [37.565777, 127.055805]
reference_loc = [37.565938, 127.055577]

# %%
# 지도 생성 (서울 좌표 기준)
m = folium.Map(location = loc_map_focus, zoom_start=18)

# folium.PolyLine(locations=line_points, color='blue', weight=5, opacity=0.8).add_to(m)
folium.Marker(start_loc, popup = "Start", icon=folium.Icon(color="red")).add_to(m)
folium.Marker(reference_loc, popup = "Ref", icon=folium.Icon(color="blue")).add_to(m)
folium.Marker([37.565898, 127.055460], popup = "Object", icon=folium.Icon(color="pink")).add_to(m)

# folium.RegularPolygonMarker(location = line_points[0], fill_color = 'blue', number_of_sides = 3, radius = 10, rotation = 100).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6e812481464ee0188fc169d5fe540ead {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6e812481464ee0188fc169d5fe540ead&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6e812481464ee0188fc169d5fe540ead = L.map(
#                 &quot;map_6e812481464ee0188fc169d5fe540ead&quot;,
#                 {
#                     center: [37.565898, 127.05546],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 18,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_52cd2969c5af8ff013b3ec9a73324522 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_52cd2969c5af8ff013b3ec9a73324522.addTo(map_6e812481464ee0188fc169d5fe540ead);
#
#
#             var marker_08e432f06139dfdf71db8461fbd3b0f1 = L.marker(
#                 [37.565777, 127.055805],
#                 {
# }
#             ).addTo(map_6e812481464ee0188fc169d5fe540ead);
#
#
#             var icon_55929e93492417935fdead54890cd9b6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7e8402669f631f2c7173625bee894cb7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2ab00cad95aae64745c2d1138c5c7d5 = $(`&lt;div id=&quot;html_b2ab00cad95aae64745c2d1138c5c7d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start&lt;/div&gt;`)[0];
#                 popup_7e8402669f631f2c7173625bee894cb7.setContent(html_b2ab00cad95aae64745c2d1138c5c7d5);
#
#
#
#         marker_08e432f06139dfdf71db8461fbd3b0f1.bindPopup(popup_7e8402669f631f2c7173625bee894cb7)
#         ;
#
#
#
#
#                 marker_08e432f06139dfdf71db8461fbd3b0f1.setIcon(icon_55929e93492417935fdead54890cd9b6);
#
#
#             var marker_40750e33535a696dcf76ca76e6e25c74 = L.marker(
#                 [37.565938, 127.055577],
#                 {
# }
#             ).addTo(map_6e812481464ee0188fc169d5fe540ead);
#
#
#             var icon_c973e761f0eae8c318aea55e1e9d3963 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_535c9e77cc19809c166d16783bfb1c51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0dbecafa1d1c83c31f67a565bcbcc8d = $(`&lt;div id=&quot;html_c0dbecafa1d1c83c31f67a565bcbcc8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ref&lt;/div&gt;`)[0];
#                 popup_535c9e77cc19809c166d16783bfb1c51.setContent(html_c0dbecafa1d1c83c31f67a565bcbcc8d);
#
#
#
#         marker_40750e33535a696dcf76ca76e6e25c74.bindPopup(popup_535c9e77cc19809c166d16783bfb1c51)
#         ;
#
#
#
#
#                 marker_40750e33535a696dcf76ca76e6e25c74.setIcon(icon_c973e761f0eae8c318aea55e1e9d3963);
#
#
#             var marker_b7fd7fcce9b3ef996c2ee1ca57144bdd = L.marker(
#                 [37.565898, 127.05546],
#                 {
# }
#             ).addTo(map_6e812481464ee0188fc169d5fe540ead);
#
#
#             var icon_0afbfbbff3f96ff52e27e2f99fbbbeb3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;pink&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_533a52df20f747a688c9ab1ba93a5a5b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b676ea86442a90341d1ff151552c6e37 = $(`&lt;div id=&quot;html_b676ea86442a90341d1ff151552c6e37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Object&lt;/div&gt;`)[0];
#                 popup_533a52df20f747a688c9ab1ba93a5a5b.setContent(html_b676ea86442a90341d1ff151552c6e37);
#
#
#
#         marker_b7fd7fcce9b3ef996c2ee1ca57144bdd.bindPopup(popup_533a52df20f747a688c9ab1ba93a5a5b)
#         ;
#
#
#
#
#                 marker_b7fd7fcce9b3ef996c2ee1ca57144bdd.setIcon(icon_0afbfbbff3f96ff52e27e2f99fbbbeb3);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Raw locations

# %%
m = folium.Map(location = loc_map_focus, zoom_start=18)
for lat, long in zip(stard_10["Latitude"], stard_10["Longitude"]):
    folium.Marker([lat, long], popup = "Start", icon=folium.Icon(color="red")).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_617ba75fa0c3fdd7f09aa3f18aee0cb0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_617ba75fa0c3fdd7f09aa3f18aee0cb0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_617ba75fa0c3fdd7f09aa3f18aee0cb0 = L.map(
#                 &quot;map_617ba75fa0c3fdd7f09aa3f18aee0cb0&quot;,
#                 {
#                     center: [37.565898, 127.05546],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 18,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f80281eeee14bc8aee50c3d4fd61b8fd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f80281eeee14bc8aee50c3d4fd61b8fd.addTo(map_617ba75fa0c3fdd7f09aa3f18aee0cb0);
#
#
#             var marker_a8fafc2757f23dba96707ee90a58d360 = L.marker(
#                 [37.56590010136153, 127.05545263376744],
#                 {
# }
#             ).addTo(map_617ba75fa0c3fdd7f09aa3f18aee0cb0);
#
#
#             var icon_5c723dcba83b344142ba3c118675da24 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9bbe6d38524d2a9db3b5aa9f2b3f82c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_627716418a1e95696de4cdb717ae1e2b = $(`&lt;div id=&quot;html_627716418a1e95696de4cdb717ae1e2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start&lt;/div&gt;`)[0];
#                 popup_9bbe6d38524d2a9db3b5aa9f2b3f82c7.setContent(html_627716418a1e95696de4cdb717ae1e2b);
#
#
#
#         marker_a8fafc2757f23dba96707ee90a58d360.bindPopup(popup_9bbe6d38524d2a9db3b5aa9f2b3f82c7)
#         ;
#
#
#
#
#                 marker_a8fafc2757f23dba96707ee90a58d360.setIcon(icon_5c723dcba83b344142ba3c118675da24);
#
#
#             var marker_d3990e89aad0622671a4e496c246ae73 = L.marker(
#                 [37.56590010136153, 127.05545263376744],
#                 {
# }
#             ).addTo(map_617ba75fa0c3fdd7f09aa3f18aee0cb0);
#
#
#             var icon_901ac4c218b7568691ec433f4cc899be = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9d3b0c2861f37c038b24bb2d0e1196d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3f06bbfbd9b1b3d4b763f7f38e4f996 = $(`&lt;div id=&quot;html_c3f06bbfbd9b1b3d4b763f7f38e4f996&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start&lt;/div&gt;`)[0];
#                 popup_9d3b0c2861f37c038b24bb2d0e1196d2.setContent(html_c3f06bbfbd9b1b3d4b763f7f38e4f996);
#
#
#
#         marker_d3990e89aad0622671a4e496c246ae73.bindPopup(popup_9d3b0c2861f37c038b24bb2d0e1196d2)
#         ;
#
#
#
#
#                 marker_d3990e89aad0622671a4e496c246ae73.setIcon(icon_901ac4c218b7568691ec433f4cc899be);
#
#
#             var marker_96276f63a8636e1cb169276ce7159d85 = L.marker(
#                 [37.56590010136153, 127.05545263376744],
#                 {
# }
#             ).addTo(map_617ba75fa0c3fdd7f09aa3f18aee0cb0);
#
#
#             var icon_5526970eb2b9dd2c3e6acc67a8678705 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_96bb5a87ff0ae67dca07cbb69df655ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa91dafb0da4732e9c595f3f04d0b95f = $(`&lt;div id=&quot;html_aa91dafb0da4732e9c595f3f04d0b95f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start&lt;/div&gt;`)[0];
#                 popup_96bb5a87ff0ae67dca07cbb69df655ed.setContent(html_aa91dafb0da4732e9c595f3f04d0b95f);
#
#
#
#         marker_96276f63a8636e1cb169276ce7159d85.bindPopup(popup_96bb5a87ff0ae67dca07cbb69df655ed)
#         ;
#
#
#
#
#                 marker_96276f63a8636e1cb169276ce7159d85.setIcon(icon_5526970eb2b9dd2c3e6acc67a8678705);
#
#
#             var marker_12cc360489960987b8d01002d64bf612 = L.marker(
#                 [37.56590010136153, 127.05545263376744],
#                 {
# }
#             ).addTo(map_617ba75fa0c3fdd7f09aa3f18aee0cb0);
#
#
#             var icon_5d1b3e586f41539d

# %%
m = folium.Map(location = loc_map_focus, zoom_start=18)
for lat, long in zip(end_10["Latitude"], end_10["Longitude"]):
    folium.Marker([lat, long], popup = "Ref", icon=folium.Icon(color="blue")).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ca7e673cbef6d4e1f535afa9ced3722 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ca7e673cbef6d4e1f535afa9ced3722&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ca7e673cbef6d4e1f535afa9ced3722 = L.map(
#                 &quot;map_3ca7e673cbef6d4e1f535afa9ced3722&quot;,
#                 {
#                     center: [37.565898, 127.05546],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 18,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_87854d27cf072e695a54be9a3843b843 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_87854d27cf072e695a54be9a3843b843.addTo(map_3ca7e673cbef6d4e1f535afa9ced3722);
#
#
#             var marker_3f1c27ab982923dfc0e2915b44ba9860 = L.marker(
#                 [37.56589879734529, 127.05544347893324],
#                 {
# }
#             ).addTo(map_3ca7e673cbef6d4e1f535afa9ced3722);
#
#
#             var icon_05f577c8d1cecdd3a81c09dcc679ab9b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_76c43b67eaac0ddb1db99a7915b0efbf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22f14eae00bfa8a6f7080195c21383f9 = $(`&lt;div id=&quot;html_22f14eae00bfa8a6f7080195c21383f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ref&lt;/div&gt;`)[0];
#                 popup_76c43b67eaac0ddb1db99a7915b0efbf.setContent(html_22f14eae00bfa8a6f7080195c21383f9);
#
#
#
#         marker_3f1c27ab982923dfc0e2915b44ba9860.bindPopup(popup_76c43b67eaac0ddb1db99a7915b0efbf)
#         ;
#
#
#
#
#                 marker_3f1c27ab982923dfc0e2915b44ba9860.setIcon(icon_05f577c8d1cecdd3a81c09dcc679ab9b);
#
#
#             var marker_cbd09ff80a8bc98f476073cfd7c0def8 = L.marker(
#                 [37.56589884491565, 127.05544381290048],
#                 {
# }
#             ).addTo(map_3ca7e673cbef6d4e1f535afa9ced3722);
#
#
#             var icon_e3ba7807e117f2a0471e3cf4b3e93298 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_57689abd74b356ba1b3b19fbd3db5f18 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39054de32af87856c302b670b63df070 = $(`&lt;div id=&quot;html_39054de32af87856c302b670b63df070&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ref&lt;/div&gt;`)[0];
#                 popup_57689abd74b356ba1b3b19fbd3db5f18.setContent(html_39054de32af87856c302b670b63df070);
#
#
#
#         marker_cbd09ff80a8bc98f476073cfd7c0def8.bindPopup(popup_57689abd74b356ba1b3b19fbd3db5f18)
#         ;
#
#
#
#
#                 marker_cbd09ff80a8bc98f476073cfd7c0def8.setIcon(icon_e3ba7807e117f2a0471e3cf4b3e93298);
#
#
#             var marker_9bf8d7223755c0e270375e284ee7d846 = L.marker(
#                 [37.56589884570702, 127.05544381845628],
#                 {
# }
#             ).addTo(map_3ca7e673cbef6d4e1f535afa9ced3722);
#
#
#             var icon_fe46d60179cc1b4f3c40c2eacdf2ff92 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_014e5a8c01c089dd0228b285db61cfc5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2231d9aedbd467d53f151b35a54d478 = $(`&lt;div id=&quot;html_b2231d9aedbd467d53f151b35a54d478&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ref&lt;/div&gt;`)[0];
#                 popup_014e5a8c01c089dd0228b285db61cfc5.setContent(html_b2231d9aedbd467d53f151b35a54d478);
#
#
#
#         marker_9bf8d7223755c0e270375e284ee7d846.bindPopup(popup_014e5a8c01c089dd0228b285db61cfc5)
#         ;
#
#
#
#
#                 marker_9bf8d7223755c0e270375e284ee7d846.setIcon(icon_fe46d60179cc1b4f3c40c2eacdf2ff92);
#
#
#             var marker_4845f458e3535ae383245fd785cf66b5 = L.marker(
#                 [37.56589884570718, 127.05544381845738],
#                 {
# }
#             ).addTo(map_3ca7e673cbef6d4e1f535afa9ced3722);
#
#
#             var icon_d0e22a32dd94132111b

# %%
m = folium.Map(location = loc_map_focus, zoom_start=18)
folium.Marker([37.565705, 127.055311], popup = "Start", icon=folium.Icon(color="red")).add_to(m)
folium.Marker([37.565938, 127.055577], popup = "End", icon=folium.Icon(color="blue")).add_to(m)
folium.Marker([37.565898, 127.055460], popup = "Obj", icon=folium.Icon(color="pink")).add_to(m)   
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0a2ec7ba1e05d56a02652e53a8b85fe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0a2ec7ba1e05d56a02652e53a8b85fe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0a2ec7ba1e05d56a02652e53a8b85fe = L.map(
#                 &quot;map_f0a2ec7ba1e05d56a02652e53a8b85fe&quot;,
#                 {
#                     center: [37.565898, 127.05546],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 18,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6bf8fd7c33d67e88428644f3ea40c194 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6bf8fd7c33d67e88428644f3ea40c194.addTo(map_f0a2ec7ba1e05d56a02652e53a8b85fe);
#
#
#             var marker_b3097b8705fbdba5ffd23364dcfe5d56 = L.marker(
#                 [37.565705, 127.055311],
#                 {
# }
#             ).addTo(map_f0a2ec7ba1e05d56a02652e53a8b85fe);
#
#
#             var icon_8d8df3b9b35c8d2973c1a9cc160d4de6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_29156883a27e851803b9d6a848c73b5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac96d6c691f23c11341433beb24882d6 = $(`&lt;div id=&quot;html_ac96d6c691f23c11341433beb24882d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start&lt;/div&gt;`)[0];
#                 popup_29156883a27e851803b9d6a848c73b5f.setContent(html_ac96d6c691f23c11341433beb24882d6);
#
#
#
#         marker_b3097b8705fbdba5ffd23364dcfe5d56.bindPopup(popup_29156883a27e851803b9d6a848c73b5f)
#         ;
#
#
#
#
#                 marker_b3097b8705fbdba5ffd23364dcfe5d56.setIcon(icon_8d8df3b9b35c8d2973c1a9cc160d4de6);
#
#
#             var marker_d1b6bda590b7512881e725476104120b = L.marker(
#                 [37.565938, 127.055577],
#                 {
# }
#             ).addTo(map_f0a2ec7ba1e05d56a02652e53a8b85fe);
#
#
#             var icon_b027ed1c2c88520582d1aeeada447a0b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_32bbc45b4b6e931e34347732b629d9f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92ea4414ee9260664ffb7faf3b0db79b = $(`&lt;div id=&quot;html_92ea4414ee9260664ffb7faf3b0db79b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;End&lt;/div&gt;`)[0];
#                 popup_32bbc45b4b6e931e34347732b629d9f6.setContent(html_92ea4414ee9260664ffb7faf3b0db79b);
#
#
#
#         marker_d1b6bda590b7512881e725476104120b.bindPopup(popup_32bbc45b4b6e931e34347732b629d9f6)
#         ;
#
#
#
#
#                 marker_d1b6bda590b7512881e725476104120b.setIcon(icon_b027ed1c2c88520582d1aeeada447a0b);
#
#
#             var marker_80b2820ed3cf1e4abc40c62bb6ee471e = L.marker(
#                 [37.565898, 127.05546],
#                 {
# }
#             ).addTo(map_f0a2ec7ba1e05d56a02652e53a8b85fe);
#
#
#             var icon_2f95bf63a149d41ea3de7485a82b9c52 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;pink&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8d96e909cf4f82c8d28fa4dc96ead7e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_056c1515072235cd23132683e4559381 = $(`&lt;div id=&quot;html_056c1515072235cd23132683e4559381&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Obj&lt;/div&gt;`)[0];
#                 popup_8d96e909cf4f82c8d28fa4dc96ead7e9.setContent(html_056c1515072235cd23132683e4559381);
#
#
#
#         marker_80b2820ed3cf1e4abc40c62bb6ee471e.bindPopup(popup_8d96e909cf4f82c8d28fa4dc96ead7e9)
#         ;
#
#
#
#
#                 marker_80b2820ed3cf1e4abc40c62bb6ee471e.setIcon(icon_2f95bf63a149d41ea3de7485a82b9c52);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
